# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Input parameters
start_year = 2015  # Adjust for start year
end_year = 2025    # Adjust for end year
start_month = 1    # Adjust for start month (1 = January)
end_month = 1     # Adjust for end month (12 = December)
company_name = "Pfizer"  # Enter the company name to search for

# Function to fetch data for a given month and year
def fetch_approvals(month, year):
    url = f"https://www.accessdata.fda.gov/scripts/cder/daf/index.cfm?event=reportsSearch.process&rptName=1&reportSelectMonth={month}&reportSelectYear={year}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://www.accessdata.fda.gov/",
        "Connection": "keep-alive",
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        table = soup.find("table")
        if table:
            rows = table.find_all("tr")
            approvals = []
            for row in rows[1:]:  # Skip the header row
                cols = row.find_all("td")
                if cols:
                    approvals.append({
                        "Approval Date": cols[0].text.strip(),
                        "Drug Name": cols[1].text.strip(),
                        "Submission": cols[2].text.strip(),
                        "Active Ingredients": cols[3].text.strip(),
                        "Sponsor": cols[4].text.strip(),
                    })
            return approvals
    return []

# Loop through all months and years in the specified range
all_approvals = []
for year in range(start_year, end_year + 1):  # Loop through years
    for month in range(start_month, end_month + 1):  # Loop through months
        print(f"Fetching data for {month}/{year}...")
        month_approvals = fetch_approvals(month, year)
        all_approvals.extend(month_approvals)

# Convert to a DataFrame
df = pd.DataFrame(all_approvals)

# Filter for the specified company
filtered_approvals = df[df["Sponsor"].str.contains(company_name, case=False, na=False)]

# Display the results
if not filtered_approvals.empty:
    print(f"Approvals for {company_name}:")
    print(filtered_approvals)
else:
    print(f"No approvals found for {company_name} in the specified time range.")

# Save all approvals to a CSV
#df.to_csv(f"fda_approvals_{start_year}_to_{end_year}.csv", index=False)
#print(f"All approvals saved to fda_approvals_{company_name}_{start_year}_to_{end_year}.csv")

# Save company-specific approvals to a separate CSV (if found)
if not filtered_approvals.empty:
    filtered_approvals.to_csv(f"{company_name}_approvals_{start_year}_to_{end_year}.csv", index=False)
    print(f"{company_name} data saved to {company_name}_approvals_{start_year}_to_{end_year}.csv")
# Out:
# Fetching data for 1/2015...
# Fetching data for 1/2016...
# Fetching data for 1/2017...
# Fetching data for 1/2018...
# Fetching data for 1/2019...
# Fetching data for 1/2020...
# Fetching data for 1/2021...
# Fetching data for 1/2022...
# Fetching data for 1/2023...
# Fetching data for 1/2024...
# Fetching data for 1/2025...
# Approvals for Pfizer:
#      Approval Date                                          Drug Name  \
# 110     01/09/2015                             PROCARDIANDA   #018482
# 111     01/09/2015                          PROCARDIA XLNDA   #019684
# 139     01/12/2015                     CAVERJECT IMPULSENDA   #021212
# 145     01/12/2015                             CLEOCIN TNDA   #050615
# 153     01/13/2015                               LONITENNDA   #018154
# 343     01/23/2015                          DEPO-PROVERANDA   #020246
# 358     01/23/2015                 DEPO-SUBQ PROVERA 104NDA   #021583
# 408     01/27/2015                               FRAGMINNDA   #020287
# 435     01/30/2015                          DEPO-PROVERANDA   #020246
# 439     01/30/2015                 DEPO-SUBQ PROVERA 104NDA   #021583
# 551     01/06/2016                              ZINECARDNDA   #020212
# 578     01/08/2016                             MINIPRESSNDA   #017442
# 741     01/15/2016                               CLEOCINNDA   #050537
# 742     01/15/2016                             CLEOCIN TNDA   #050537
# 743     01/15/2016                             CLEOCIN TNDA   #050600
# 744     01/15/2016                             CLEOCIN TNDA   #050615
# 815     01/21/2016                 CLEOCIN HYDROCHLORIDENDA   #050162
# 1201    01/09/2017                     DEPO-TESTOSTERONEANDA  #085635
# 1375    01/26/2017                               FRAGMINNDA   #020287
# 1381    01/26/2017                                TOVIAZNDA   #022030
# 1439    01/31/2017                 DEPO-SUBQ PROVERA 104NDA   #021583
# 1510    01/18/2018                             MERREM IVNDA   #050706
# 1521    01/22/2018                              DIFLUCANNDA   #019949
# 1522    01/22/2018                              DIFLUCANNDA   #020090
# 1825    01/17/2019                           ALDACTAZIDENDA   #012616
# 2162    01/16/2020                                 IXIFIBLA   #761072
# 2275    01/24/2020                             TRAZIMERABLA   #761081
# 2358    01/30/2020                             CAMPTOSARNDA   #020571
# 2532    01/15/2021                            AZULFIDINENDA   #007073
# 2533    01/15/2021                    AZULFIDINE EN-TABSNDA   #007073
# 2631    01/22/2021                              LORBRENANDA   #210868
# 2793    01/06/2022                             ZITHROMAXNDA   #050733
# 2909    01/14/2022                               CIBINQONDA   #213871
# 3021    01/27/2022                             CAMPTOSARNDA   #020571
# 3022    01/27/2022                             CAMPTOSARNDA   #020571
# 3217    01/13/2023                               HALCIONNDA   #017892
# 3246    01/17/2023                              DIFLUCANNDA   #019949
# 3247    01/17/2023  DIFLUCAN IN DEXTROSE 5% IN PLASTIC CONTAINERND...
# 3248    01/17/2023      DIFLUCAN IN SODIUM CHLORIDE 0.9%NDA   #019950
# 3249    01/17/2023  DIFLUCAN IN SODIUM CHLORIDE 0.9% IN PLASTIC CO...
# 3250    01/17/2023                              DIFLUCANNDA   #020090
# 3483    01/31/2023                               SYNARELNDA   #019886
# 4082    01/17/2025                               ELELYSOBLA   #022458
#
#      Submission                   Active Ingredients     Sponsor
# 110    SUPPL-52                           NIFEDIPINE      PFIZER
# 111    SUPPL-29                           NIFEDIPINE      PFIZER
# 139    SUPPL-12                          ALPROSTADIL      PFIZER
# 145    SUPPL-13                CLINDAMYCIN PHOSPHATE      PFIZER
# 153    SUPPL-26                            MINOXIDIL      PFIZER
# 343    SUPPL-54          MEDROXYPROGESTERONE ACETATE      PFIZER
# 358    SUPPL-26          MEDROXYPROGESTERONE ACETATE      PFIZER
# 408    SUPPL-62                    DALTEPARIN SODIUM      PFIZER
# 435    SUPPL-53          MEDROXYPROGESTERONE ACETATE      PFIZER
# 439    SUPPL-25          MEDROXYPROGESTERONE ACETATE      PFIZER
# 551    SUPPL-18            DEXRAZOXANE HYDROCHLORIDE      PFIZER
# 578    SUPPL-44               PRAZOSIN HYDROCHLORIDE      PFIZER
# 741    SUPPL-37                CLINDAMYCIN PHOSPHATE      PFIZER
# 742    SUPPL-37                CLINDAMYCIN PHOSPHATE      PFIZER
# 743    SUPPL-14                CLINDAMYCIN PHOSPHATE      PFIZER
# 744    SUPPL-14                CLINDAMYCIN PHOSPHATE      PFIZER
# 815    SUPPL-94            CLINDAMYCIN HYDROCHLORIDE      PFIZER
# 1201   SUPPL-38               TESTOSTERONE CYPIONATE      PFIZER
# 1375   SUPPL-68                    DALTEPARIN SODIUM      PFIZER
# 1381   SUPPL-12                FESOTERODINE FUMARATE      PFIZER
# 1439   SUPPL-23          MEDROXYPROGESTERONE ACETATE      PFIZER
# 1510   SUPPL-39                            MEROPENEM      PFIZER
# 1521   SUPPL-68                          FLUCONAZOLE      PFIZER
# 1522   SUPPL-49                          FLUCONAZOLE      PFIZER
# 1825   SUPPL-78  HYDROCHLOROTHIAZIDE; SPIRONOLACTONE      PFIZER
# 2162    SUPPL-6                      INFLIXIMAB-QBTX  PFIZER INC
# 2275    SUPPL-2                     TRASTUZUMAB-QYYP  PFIZER INC
# 2358   SUPPL-51             IRINOTECAN HYDROCHLORIDE  PFIZER INC
# 2532  SUPPL-129                        SULFASALAZINE      PFIZER
# 2533  SUPPL-129                        SULFASALAZINE      PFIZER
# 2631    SUPPL-2                           LORLATINIB      PFIZER
# 2793   SUPPL-49                         AZITHROMYCIN      PFIZER
# 2909     ORIG-1                          ABROCITINIB      PFIZER
# 3021   SUPPL-52             IRINOTECAN HYDROCHLORIDE  PFIZER INC
# 3022   SUPPL-53             IRINOTECAN HYDROCHLORIDE  PFIZER INC
# 3217   SUPPL-57                            TRIAZOLAM      PFIZER
# 3246   SUPPL-73                          FLUCONAZOLE      PFIZER
# 3247   SUPPL-72                          FLUCONAZOLE      PFIZER
# 3248   SUPPL-72                          FLUCONAZOLE      PFIZER
# 3249   SUPPL-72                          FLUCONAZOLE      PFIZER
# 3250   SUPPL-54                          FLUCONAZOLE      PFIZER
# 3483   SUPPL-39                    NAFARELIN ACETATE      PFIZER
# 4082   SUPPL-33                   TALIGLUCERASE ALFA      PFIZER
# Pfizer data saved to Pfizer_approvals_2015_to_2025.csv
